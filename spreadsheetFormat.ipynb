# %%
import pandas as pd
import numpy as np

# %%
diary=pd.read_csv("C:/Users/yumeng.zou/Google Drive/Freshyear/Summer/Research/1819 diary.csv")

# %%
diary.head()
# Out:
#        Date Time       Type Subtype Place Participants Participants.1  \
# 0  23-12-09  NaN  Education     NaN   麗澤軒          NaN            NaN
# 1  23-12-10  NaN    Reading     NaN   NaN          NaN            NaN
# 2  23-12-13  NaN  Education     NaN   NaN          NaN            NaN
# 3  23-12-18  NaN  Education     NaN   NaN          NaN            NaN
# 4  24-01-23  NaN  Education     NaN   NaN          NaN            NaN
#
#   Participants.2 Participants.3 Participants.4     ...      Unnamed: 16  \
# 0            NaN            NaN            NaN     ...              NaN
# 1            NaN            NaN            NaN     ...              NaN
# 2            NaN            NaN            NaN     ...              NaN
# 3            NaN            NaN            NaN     ...              NaN
# 4            NaN            NaN            NaN     ...              NaN
#
#    Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# ...

# %%
diary.index
# Out:
# RangeIndex(start=0, stop=995, step=1)

# %%
diary.columns
# Out:
# Index([u'Date', u'Time', u'Type', u'Subtype', u'Place', u'Participants',
#        u'Participants.1', u'Participants.2', u'Participants.3',
#        u'Participants.4', u'Participants.5', u'Unnamed: 11', u'Unnamed: 12',
#        u'Unnamed: 13', u'Unnamed: 14', u'Unnamed: 15', u'Unnamed: 16',
#        u'Unnamed: 17', u'Unnamed: 18', u'Unnamed: 19', u'Unnamed: 20',
#        u'Unnamed: 21', u'Unnamed: 22', u'Unnamed: 23', u'Unnamed: 24',
#        u'Unnamed: 25'],
#       dtype='object')

# %%
diary.dropna(how='all',inplace=True)
diary.dropna(axis=1,how='all',inplace=True)
diary.tail()
# Out:
#          Date Time       Type Subtype Place Participants Participants.1  \
# 551       NaN  NaN  Go_places     NaN   月林堂          黎楷屏            NaN
# 552  24-09-01  NaN         寫字     NaN   NaN          NaN            NaN
# 553       NaN  NaN    Reading     NaN   NaN          NaN            NaN
# 554       NaN  NaN    Visited     Yes   NaN          黎楷屏            NaN
# 555       NaN  NaN    Visited     Yes   NaN          蔡七婿            NaN
#
#     Participants.2 Participants.3 Participants.4 Participants.5
# 551            NaN            NaN            NaN            NaN
# 552            NaN            NaN            NaN            NaN
# 553            NaN            NaN            NaN            NaN
# 554            NaN            NaN            NaN            NaN
# 555            NaN            NaN            NaN            NaN

# %%
mid=diary[['Type','Subtype','Participants','Participants.1','Participants.2','Participants.3','Participants.4','Participants.5']]
mid.set_index(['Type','Subtype'],inplace=True)
mid
# Out:
#                          Participants Participants.1 Participants.2  \
# Type           Subtype
# Education      NaN                NaN            NaN            NaN
# Reading        NaN                NaN            NaN            NaN
# Education      NaN                NaN            NaN            NaN
#                NaN                NaN            NaN            NaN
#                NaN                NaN            NaN            NaN
#                NaN                NaN            NaN            NaN
#                NaN                NaN            NaN            NaN
#                NaN                NaN            NaN            NaN
#                NaN                NaN            NaN            NaN
#                NaN                NaN            NaN            NaN
# Marriage       NaN                謝念紹             麥氏            NaN
# Education      NaN                 吴錦            NaN            NaN
# ...
