# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\yumeng.zou\\AnacondaProjects\\diary'

# %%
import diaryLib7_12 as mylib

# %%
DG1=pd.read_csv("/Users/yumeng.zou/Google Drive/Freshyear/Summer/Research/DG1 diary.csv")
JQ24=pd.read_csv("/Users/yumeng.zou/Google Drive/Freshyear/Summer/Research/JQ24 diary.csv")
JQ25=pd.read_csv("/Users/yumeng.zou/Google Drive/Freshyear/Summer/Research/JQ25 diary.csv")

# %%
DG1.head()
# Out:
#       Date Weather Time      Type Preposition Notes Place Participants  \
# 0  DG1-1-1     NaN    早  Ceremony         NaN  神及先祖   NaN          NaN
# 1      NaN     NaN  NaN  Ceremony         NaN    拜年    大宅          NaN
# 2      NaN     NaN  NaN       NaN         NaN   NaN    二宅          NaN
# 3      NaN     NaN  NaN       NaN         NaN   NaN    三宅          NaN
# 4      NaN     NaN  NaN       NaN         NaN   NaN    四宅          NaN
#
#    Unnamed: 8
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
JQ24.head()
# Out:
#          Date Weather Time       Type Note Place Direction Participants  \
# 0  JQ23-12-09     NaN  NaN  Education  NaN   麗澤軒       NaN          NaN
# 1  JQ23-12-10     NaN  NaN  Education  NaN   NaN       NaN          NaN
# 2  JQ23-12-13     NaN  NaN  Education  NaN   NaN       NaN          NaN
# 3  JQ23-12-18     NaN  NaN  Education  NaN   NaN       NaN          NaN
# 4  JQ24-01-23     NaN  NaN  Education  NaN   NaN       NaN          NaN
#
#    Unnamed: 8  Unnamed: 9     ...       Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# 0         NaN         NaN     ...               NaN          NaN          NaN
# 1         NaN         NaN     ...               NaN          NaN          NaN
# 2         NaN         NaN     ...               NaN          NaN          NaN
# 3         NaN         NaN     ...               NaN          NaN          NaN
# 4         NaN         NaN     ...               NaN          NaN          NaN
#
# ...

# %%
JQ25.head()
# Out:
#      Date     Time      Type   Subtype Place Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0  25-1-1  Morning  Ceremony  Ancestor   NaN        NaN        NaN        NaN
# 1  25-1-1  Morning        拜年       NaN    大宅        NaN        NaN        NaN
# 2  25-1-1  Morning        拜年       NaN   各衙门        NaN        NaN        NaN
# 3  25-1-1  Morning        拜年       NaN    志局        NaN        NaN        NaN
# 4  25-1-1  Morning        拜年       NaN    三宅        NaN        NaN        NaN
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0        NaN        NaN         NaN         NaN         NaN
# 1        NaN        NaN         NaN         NaN         NaN
# 2        NaN        NaN         NaN         NaN         NaN
# 3        NaN        NaN         NaN         NaN         NaN
# 4        NaN        NaN         NaN         NaN         NaN

# %%
DG1.dropna(axis=[0,1],how='all',inplace=True)
JQ24.dropna(axis=[0,1],how='all',inplace=True)
JQ25.dropna(axis=[0,1],how='all',inplace=True)
DG1.head()
# Out:
#       Date Weather Time      Type Preposition Notes Place Participants
# 0  DG1-1-1     NaN    早  Ceremony         NaN  神及先祖   NaN          NaN
# 1      NaN     NaN  NaN  Ceremony         NaN    拜年    大宅          NaN
# 2      NaN     NaN  NaN       NaN         NaN   NaN    二宅          NaN
# 3      NaN     NaN  NaN       NaN         NaN   NaN    三宅          NaN
# 4      NaN     NaN  NaN       NaN         NaN   NaN    四宅          NaN

# %%
cat=pd.concat([JQ24,DG1])
cat
# Out:
#             Date Direction  Note   Notes Participants  Place Preposition  \
# 0     JQ23-12-09       NaN   NaN     NaN          NaN    麗澤軒         NaN
# 1     JQ23-12-10       NaN   NaN     NaN          NaN    NaN         NaN
# 2     JQ23-12-13       NaN   NaN     NaN          NaN    NaN         NaN
# 3     JQ23-12-18       NaN   NaN     NaN          NaN    NaN         NaN
# 4     JQ24-01-23       NaN   NaN     NaN          NaN    NaN         NaN
# 5     JQ24-01-24       NaN   NaN     NaN          NaN    NaN         NaN
# 6     JQ24-01-28       NaN   NaN     NaN          NaN    NaN         NaN
# 7     JQ24-01-29       NaN   NaN     NaN          NaN    NaN         NaN
# 8     JQ24-02-02       NaN   NaN     NaN          NaN    NaN         NaN
# 9     JQ24-02-08       NaN   NaN     NaN          NaN    NaN         NaN
# 10           NaN       NaN    三男     NaN          謝念紹    NaN         NaN
# 11           NaN       NaN   NaN     NaN           麥氏    NaN         NaN
# ...

# %%
mylib.ppl(cat,"/Users/yumeng.zou/Downloads")
mylib.ppl_plc(cat,"/Users/yumeng.zou/Downloads")

# %%
ppl=pd.DataFrame(pd.concat([DG1["Participants"],JQ24["Participants"],JQ25["Participants"]])).dropna().drop_duplicates()
ppl
# Out:
#      Participants
# 7              東川
# 8             羅太尊
# 10             楷屏
# 12             季彤
# 14             □齋
# 16            端明師
# 20             澄公
# 21             龍淵
# 22             香石
# 23             退谷
# 36            魏世兄
# 38             銘山
# 39            陳羅山
# 42            阮制軍
# 44             漸公
# 47             墨池
# 48             清湖
# 51            至道師
# 54             至公
# 57             平湖
# 58             南洲
# 59             興雲
# 63              李
# 64              潘
# 65              葉
# 66              沈
# 68            李道士
# 69            黄一桂
# 71            建融師
# 75             南邨
# ...           ...
# 1012          陳喬梓
# 1016          锺輝垣
# 1020           春波
# 1022     花埭判春園（人）
# 1028           諸僧
# 1029         姚十二兄
# 1044           秀甫
# 1047           醴泉
# 1054          李光藻
# 1071          鍾輝垣
# 1079        鄉間琮鵬侄
# 1104           泉兄
# 1105          麗生子
# 1116         船户温琪
# 1132          徐牧庵
# 1139           石君
# 1140   凡十四人，皆吾輩同學
# 1161          有蘭亭
# ...

# %%
ppl.to_csv("/Users/yumeng.zou/Downloads/pplNames.csv")
